# %%
from pprint import pprint

import pandas as pd
from zbaseballdata.client import ZBaseballDataClient

client = ZBaseballDataClient("USERNAME", "PASSWORD")

# %% [markdown]
# # Pull Hitting Statistics

# %% [markdown]
# #### The function definition for the Python Client.
# ```python
# def get_batting_stat_split(
#     self,
#     retro_id: str,
#     stats: List[str],           # E.g. ["H", "SO", "OPS", "BB"]
#     agg_by: str,
#     vs_pitcher: str = None,     # a pitchers retro_id
#     game_type: str = None,      # ALCS, POST, REG, WS, NLWC, etc... None is all games
#     pitcher_throw: str = None,  # R/L (None for all)
#     start_date: str = None,     # String of the form YYYY-MM-DD
#     end_date: str = None,       # String of the form YYYY-MM-DD
#     year: int = None,           # Or simply use this to filter by year.
# ):
# ```
#
# The return type is a dictionary, which has keys as stats, and values as dictionaries. These dictionaries have values as the split-datum mapping.
#
# The return values can be passed directly into pd.DataFrame to return a nicely formatted pandas dataframe.
#
# Valid Stats to choose from:
#  - PA
#  - AB
#  - H
#  - 2B
#  - 3B
#  - HR
#  - BB
#  - IBB
#  - SO
#  - ROE
#  - GIDP
#  - SH (sac hits)
#  - SF
#  - G (games played)
#  - HBP
#  - RBI
#  - R (runs scored)
#  - SB
#  - CS
#  - GB (ground balls hit)
#  - FB (fly balls hit)
#  - PF (pop flies hit)
#  - LD (line drives hit)
#  - AVG
#  - OBP
#  - SLG
#  - OPS
#
# Valid `agg_by` arguments (how to aggregate data "row-wise"):
#  - C (by career totals)
#  - D (by day - Double headers aggregate to a single day)
#  - G (by game / retrosheet unique game id)
#  - W (by week)
#  - M (by month)
#  - MY (by month/year)
#  - Y (by year)
#  - DOW (by day of the week)
#  - INN (by inning)
#  - COP (by count on play)
#  - PARK_ID (by retrosheet park ID, see /api/v1/parks/)
#  - PARK_NAME (by human readable park name)
#  - DAYNIGHT (split by day/night)
#  - BATTINGORDER (by order in the lineup)
#  - FIELD_POS (by position in the field)
#  - BY_OPP_TEAM (by opposing team)
#  - BY_BASES_OCCUPIED (by how the bases are filled when the event occured)
#  - VS_PITCHER_HAND (RHP / LHP)
#  - HOME_AWAY (by home / away)

# %% [markdown]
# ## Some Basic Examples Below
#
# This is not an exhaustive list of examples, but hopefully can show the strengths of using the Python Client.

# %% [markdown]
# ### Career Stats

# %%
jeter_id = next(client.get_players(search="derek jeter"))["retro_id"]
requested_stats = [
    "H",
    "SO",
    "AB",
    "2B",
    "3B",
    "BB",
    "HR",
    "OPS",
]

# Career including postseason (but not spring training). If only regular season required, 
# set game_type="REG" in the call below. 
client.get_batting_stat_split(
    retro_id=jeter_id, 
    stats=requested_stats,
    agg_by="C",
)
# Out:
# {'H': {'career': 3665},
#  'SO': {'career': 1975},
#  'AB': {'career': 11845},
#  '2B': {'career': 576},
#  '3B': {'career': 71},
#  'BB': {'career': 1148},
#  'HR': {'career': 280},
#  'OPS': {'career': 0.818}}

# %% [markdown]
# ### Stats by day

# %%
jeter_id = next(client.get_players(search="derek jeter"))["retro_id"]
requested_stats = [
    "H",
    "SO",
    "AB",
    "2B",
    "3B",
    "BB",
    "HR",
    "OPS",
]

# Output not shown, as it's quite large
_ = client.get_batting_stat_split(
    retro_id=jeter_id, 
    stats=requested_stats,
    agg_by="D",
)

# %% [markdown]
# ### Stats filtered by date range

# %%
requested_stats = [
    "AVG",
    "SLG",
    "IBB"
]

res = client.get_batting_stat_split(
    retro_id=jeter_id, 
    stats=requested_stats,
    agg_by="C",
    start_date="2014-05-01",
    end_date="2014-06-01",
)

pprint(res)
# Can also easily pass into pandas dataframe

pd.DataFrame(res)
# Out:
# {'AVG': {'career': 0.274}, 'IBB': {'career': 0}, 'SLG': {'career': 0.34}}
#           AVG   SLG  IBB
# career  0.274  0.34    0

# %% [markdown]
# ### Date Range - Different "agg_by"

# %%
res = client.get_batting_stat_split(
    retro_id=jeter_id, 
    stats=["H", "HR", "2B", "BB", "OPS"],
    agg_by="DOW",
    start_date="2014-05-01",
    end_date="2014-06-01",
)
pd.DataFrame(res)
# Out:
#      H  HR  2B  BB    OPS
# fri  3   0   0   1  0.378
# mon  6   0   1   1  1.038
# sat  4   0   1   0  0.693
# sun  8   0   0   0  0.783
# thu  1   0   0   1  0.258
# tue  3   0   0   4  0.721
# wed  4   1   0   0  0.688

# %%
res = client.get_batting_stat_split(
    retro_id=jeter_id, 
    stats=requested_stats,
    agg_by="D",
    start_date="2014-05-01",
    end_date="2014-06-01",
)
pd.DataFrame(res)
# Out:
#               AVG    SLG  IBB
# 2014-05-01  0.250  0.250    0
# 2014-05-02  0.000  0.000    0
# 2014-05-04  0.000  0.000    0
# 2014-05-05  0.500  0.750    0
# 2014-05-06  0.500  0.500    0
# 2014-05-07  0.400  1.000    0
# 2014-05-09  0.000  0.000    0
# 2014-05-11  0.200  0.200    0
# 2014-05-12  0.750  0.750    0
# 2014-05-13  0.000  0.000    0
# 2014-05-14  0.250  0.250    0
# 2014-05-15  0.000  0.000    0
# 2014-05-17  0.500  0.500    0
# 2014-05-18  0.400  0.400    0
# 2014-05-20  0.500  0.500    0
# 2014-05-21  0.143  0.143    0
# 2014-05-22  0.000  0.000    0
# 2014-05-23  0.500  0.500    0
# 2014-05-24  0.000  0.000    0
# 2014-05-25  0.800  1.200    0
# 2014-05-26  0.200  0.200    0
# 2014-05-27  0.000  0.000    0
# 2014-05-30  0.250  0.250    0
# 2014-05-31  0.500  0.750    0
# 2014-06-01  0.250  0.250    0

# %% [markdown]
# ### Stats vs. a Specific Pitcher, between specific dates

# %%
# Aaron Judge vs. J.A. Happ All time before July in 2018, broken down by day
res = client.get_batting_stat_split(
    retro_id="judga001", 
    stats=["H", "OPS", "BB", "SO"],
    agg_by="D",
    end_date="2018-06-30",
    vs_pitcher="happj001",
)
pd.DataFrame(res)
# Out:
#             H    OPS  BB  SO
# 2016-08-17  1  0.666   0   2
# 2017-07-04  1  1.666   0   2
# 2017-08-08  0  0.667   2   1
# 2018-03-29  1  1.667   1   1

# %% [markdown]
# ### Tex vs. LHP

# %%
# Mark Teixiera Stats vs. LHP, by year
res = client.get_batting_stat_split(
    retro_id="teixm001", 
    stats=["H", "OPS", "BB", "SO"],
    agg_by="Y",
    pitcher_throw="L",
)
pd.DataFrame(res)
# Out:
#        H    OPS  BB  SO
# 2003  51  0.923  17  38
# 2004  51  0.959  18  38
# 2005  50  0.858  17  33
# 2006  51  0.977  20  42
# 2007  55  1.000  21  33
# 2008  63  0.910  41  29
# 2009  59  0.882  29  33
# 2010  52  0.918  41  34
# 2011  58  0.971  22  25
# 2012  51  0.866  20  28
# 2013   5  0.935   4   6
# 2014  27  0.691  19  24
# 2015  27  0.786  27  19
# 2016  25  0.684  20  23

# %%
# Mark Teixiera All time REG season career Stats vs. LHP, by park
res = client.get_batting_stat_split(
    retro_id="teixm001", 
    stats=["H", "OPS", "BB", "SO"],
    agg_by="PARK_NAME",
    pitcher_throw="L",
    game_type="REG",
)
pd.DataFrame(res)
# Out:
#                                              H    OPS  BB  SO
# Angel Stadium of Anaheim                    20  0.748  18   6
# AT&T Park                                    0  0.000   0   2
# Busch Stadium III                            1  1.000   0   0
# Chase Field                                  3  1.833   2   1
# Citi Field                                   3  0.600   3   2
# Citizens Bank Park                           6  0.786   2   8
# Comerica Park                               17  0.961   8  13
# Coors Field                                  1  0.708   2   1
# Dodger Stadium                               0  0.000   0   1
# Fenway Park                                 17  0.972  16  12
# Great American Ballpark                      7  0.969   2   5
# Guaranteed Rate Field;U.S. Cellular Field   24  1.000   7  17
# Hubert H. Humphrey Metrodome                 4  0.749   0   5
# Kauffman Stadium                            12  0.884  10   7
# Miller Park                                  0  0.333   1   0
# Minute Maid Park                             9  0.867   2   7
# Nationals Park                               6  1.233   6   1
# Oakland-Alameda County Coliseum             38  1.078  15  19
# Oriole Park at Camden Yards                 20  1.079  10   9
# PETCO Park                                   1  0.375   0   1
# PNC Park                                     3  1.867   1   0
# Progressive Field                           16  1.161   6   7
# Rangers Ballpark in Arlington              121  0.932  46  80
# Robert F. Kennedy Stadium                    2  1.200   0   1
# Rogers Centre                               29  0.753  16  23
# Safeco Field                                27  0.851   8  22
# Shea Stadium                                 4  0.643   0   1
# Sun Life Stadium                             7  0.560   0   5
# Target Field                                 7  1.208   4   2
# The Ballpark at Disney's Wide World          3  2.833   2   0
# Tropicana Field                             22  0.957   9  14
# Turner Field                                32  0.871  24  23
# Wrigley Field                                1  0.444   3   1
# Yankee Stadium I                             9  0.965   2   6
# Yankee Stadium II                          136  0.827  79  92
